# %%
# 라이브러리 임포트, 복붙하세요
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm           # 한글 폰트 깨짐방지 설정
import matplotlib.pyplot as plt
import networkx as nx

# Matplotlib에 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows
plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows
# plt.rcParams['font.family'] = 'AppleGothic'  # macOS
# plt.rcParams['font.family'] = 'NanumGothic'  # Linux에서 나눔고딕 사용
plt.rcParams['axes.unicode_minus'] = False     # 폰트 깨짐 방지를 위해 음수 기호 설정
font_name = 'Malgun Gothic'  # 네트워크x 라이브러리 한글 깨짐 방지를 위한 font_family 변수 지정

# %%
# 빈그래프 만들기
G = nx.Graph()
plt.figure(figsize=(4,2)) # 작게 시작
plt.title('Network Graph 연습')
nx.draw(G)

# %%
# 노드 추가하기 add_node() 함수 사용

# %%
# 엣지 추가하기 add_edge() 함수 사용

# %%
# 그래프 함수를 만들어보자. *args, **kwargs 키워드 매개변수 활용

# %%
# 인접행렬 만들기

# %%
# 가라테 클럽 네트워크
G = nx.karate_club_graph()
# 2) 기본 정보 확인
print("노드 수:", G.number_of_nodes())
print("엣지 수:", G.number_of_edges())
# Out:
# 노드 수: 34
# 엣지 수: 78

# %%
# 3) 네트워크 시각화
plt.figure(figsize=(8, 8))
nx.draw(G, with_labels=True, node_size=500, font_size=10)
plt.show()

# %%
# 커뮤니티 탐지
from networkx.algorithms.community import greedy_modularity_communities

# %%
# 에고 그래프

# %%
# 중심성(degree)

# %%
# 매개중심성(Betweenness)
