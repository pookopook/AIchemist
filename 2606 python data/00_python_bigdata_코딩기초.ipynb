# %% [markdown]
# * 순서
# * ㅇㅇ

# %% [markdown]
# # 제목
# * 노트 정리를 할 수 있다.
#
# ## 소제목(2단)
# 1. 일번
# 2.
# #### 더작은제목(4단)
# - [ ] 체크리스트1번
# - [x] 2번
# - [ ] 3번체크리스트
# - [ ]
# $\frac{분자a}{분모b}$
# $$ \begin{cases} ax + by = c \\ dx + ey = f \end{cases} $$

# %% [markdown]
# ## 중간과정

# %%
# 원래 셀

# %%
print('안녕하세요')
# Out:
# 안녕하세요. 파이썬입니다.

# %%
a = '안녕하세요'

# %%
print(a)
# Out:
# 안녕하세요

# %%
안녕하세요 = 5

# %%
# 주석 +- * /
7 // 2 , 7 % 2
# Out:
# (3, 1)

# %%
7 / 2
# Out:
# 3.5

# %%
2 ** 3   #  2^3
# Out:
# 8

# %%
a = '1'
type(a)
# Out:
# str

# %%
type(1), type(3.5), type('안녕')
# Out:
# (int, float, str)

# %%
a
# Out:
# '1'

# %%
a + 1
# a가 문자열이기 때문에 숫자 1과 더할 수 없어서 에러가 발생합니다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 a + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = ['첫번째',2,3,4,5,'여섯',7]

# %%
a[0:7:2]   #a[first:last:step]
# Out:
# ['첫번째', 3, 5, 7]

# %%
a = '위원회에 따르면 정부와 공공기관이 관행적으로 사용해 온 한글 문서'

# %%
a[100:0:-1]   ## 빈칸도 문자다.
# Out:
# '서문 글한 온 해용사 로으적행관 이관기공공 와부정 면르따 에회원'

# %%
a = [175, 2, 3, 4]
person = {
    '이름' : '정준엽',
    '키' : 175,
    '몸무게' :  70,
    '혈액형' : 'A',
    'MBTI' : 'ISTP'
}

# %%
key = next(k for k, v in person.items() if v == 175)
key
# Out:
# '키'

# %%
for k, v in person.items():
    # print(k, v)
    if v == 175:
        print(k)
# Out:
# 키

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')
# Out:
# C:\Users\pooko\anaconda3\envs\bibiml\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Users\pooko\anaconda3\envs\bibiml\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
df.head(3)
# Out:
#     거래ID       거래일자  직원ID  직원명     부서  지역    판매채널  고객유형    제품군       제품명  \
# 0  T0001 2026-02-16  E001  김민준   영업1팀  서울  오프라인매장  소상공인    노트북  비즈니스 노트북
# 1  T0002 2026-05-08  E007  조성민  기업영업팀  대전    온라인몰    개인    노트북      울트라북
# 2  T0003 2026-01-10  E009  장도윤  영업지원팀  광주    기업계약  중소기업  소프트웨어  오피스 라이선스
#
#         단가  판매량   할인율      매출액       원가       이익  결제수단  고객만족도 반품여부
# 0  1250000    5  0.05  5937500  4500000  1437500    현금      5    N
# 1  1580000    4  0.00  6320000  4676800  1643200  계좌이체      3    N
# 2   220000    9  0.15  1683000   752400   930600  후불결제      4    N

# %%
df['할인후매출액'] = df['단가'] * df['판매량'] * ( 1 - df['할인율']) # 할인후매출액

# %%
df.to
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_excel('결과.xlsx', index=False)

# %%
import os
os.startfile(os.getcwd())

# %%
print(1)
# Out:
# 1
